# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt

plt.style.use(['ggplot', './neo-light.mplstyle'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plt.title("HELLO")
plt.plot([1,1.5,2.5,2.8])
